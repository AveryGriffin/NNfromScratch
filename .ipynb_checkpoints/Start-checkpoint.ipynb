# %%
from PIL import Image, ImageDraw, ImageFont
from matplotlib import pyplot as plt
from matplotlib import image
import numpy as np
from numpy import asarray
import os
# import scipy.optimize as opt

# %%
"""def convert_RGB(path):
    for item in os.listdir(path):
        if os.path.isfile(path + item):
            im = Image.open(path + item)
            if im.mode != 'RGB':
                im_RGB = im.convert("RGB")
                im_RGB.save(str(path+item), 'JPEG', quality=90)
            else:
                print("is already RGB")
            im.close()
        else:
            print("image path not found")"""

# %%
def convert_RGB(image):
    im_RGB = im.convert("RGB")
    return im_RGB

# %%
"""def resize(path):
    for item in os.listdir(path):
        if os.path.isfile(path + item):
            im = Image.open(path + item)
            im = im.resize((80,80), Image.ANTIALIAS)
            im.save(str(path+item), 'JPEG', quality=90)
            im.close
        else:
            print("Resize path not found")"""
# Out:
# 'def resize(path):\n    for item in os.listdir(path):\n        if os.path.isfile(path + item):\n            im = Image.open(path + item)\n            im = im.resize((80,80), Image.ANTIALIAS)\n            im.save(str(path+item), \'JPEG\', quality=90)\n            im.close\n        else:\n            print("Resize path not found")'

# %%
def resize(path):
    im_resize = im.resize((80,80), Image.ANTIALIAS)
    return im_resize

# %%
def process_image(path):
    for item in os.listdir(path):
        if os.path.isfile(path + item):
            im = Image.open(path + item)
            if im.mode != 'RGB':
                im = convert_RGB(im)
            else:
                print("File already RGB")
            im = resize(im)
            im.save(str(path+item), 'JPEG', quality=90)
            im.close()
        else:
            print("Path not found")

# %%
def print_modeANDsize(path):
    for item in os.listdir(path):
        if os.path.isfile(path+item):
            im = Image.open(path + item)
            print(im.mode, im.size, im.format, "   ", item)

# %%
print_modeANDsize("CALIBRATION IMAGES/DarthVader - Copy/")
# Out:
# RGB (89, 50) JPEG     download (1).jfif
# RGB (66, 50) JPEG     download (10).jfif
# RGB (300, 168) JPEG     download (11).jfif
# RGB (225, 225) JPEG     download (12).jfif
# RGB (222, 227) JPEG     download (13).jfif
# RGB (218, 231) JPEG     download (14).jfif
# RGB (225, 225) JPEG     download (15).jfif
# RGB (300, 168) JPEG     download (16).jfif
# RGB (176, 287) JPEG     download (17).jfif
# RGB (225, 225) JPEG     download (18).jfif
# RGB (225, 225) JPEG     download (19).jfif
# RGB (50, 64) JPEG     download (2).jfif
# RGB (191, 264) JPEG     download (20).jfif
# RGB (225, 225) JPEG     download (22).jfif
# RGB (188, 268) JPEG     download (23).jfif
# RGB (173, 291) JPEG     download (24).jfif
# RGB (225, 225) JPEG     download (25).jfif
# RGB (310, 163) JPEG     download (26).jfif
# RGB (300, 168) JPEG     download (27).jfif
# RGB (234, 216) JPEG     download (28).jfif
# RGB (300, 168) JPEG     download (29).jfif
# RGB (82, 50) JPEG     download (3).jfif
# ...

# %%
convert_RGB("CALIBRATION IMAGES/DarthVader/")
# Out:
# is already RGB
# is already RGB
# is already RGB
# is already RGB
# is already RGB
# is already RGB
# is already RGB
# is already RGB
# is already RGB
# is already RGB
# is already RGB
# is already RGB
# is already RGB
# is already RGB
# is already RGB
# is already RGB
# is already RGB
# is already RGB
# is already RGB
# is already RGB
# is already RGB
# is already RGB
# is already RGB
# is already RGB
# is already RGB
# is already RGB
# is already RGB
# is already RGB
# is already RGB
# is already RGB
# is already RGB
# is already RGB
# is already RGB
# is already RGB
# is already RGB
# is already RGB
# is already RGB
# is already RGB
# is already RGB
# is already RGB
# is already RGB
# is already RGB
# is already RGB
# is already RGB
# is already RGB
# is already RGB
# is already RGB
# is already RGB
# is already RGB
# is already RGB
# is already RGB
# is already RGB
# is already RGB
# is already RGB
# is already RGB
# is already RGB
# is already RGB
# is already RGB
# ...

# %%
resize("CALIBRATION IMAGES/DarthVader/")

# %%
print_modeANDsize("CALIBRATION IMAGES/DarthVader/")
# Out:
# RGB (80, 80) JPEG     download (1).jfif
# RGB (80, 80) JPEG     download (10).jfif
# RGB (80, 80) JPEG     download (11).jfif
# RGB (80, 80) JPEG     download (12).jfif
# RGB (80, 80) JPEG     download (13).jfif
# RGB (80, 80) JPEG     download (14).jfif
# RGB (80, 80) JPEG     download (15).jfif
# RGB (80, 80) JPEG     download (16).jfif
# RGB (80, 80) JPEG     download (17).jfif
# RGB (80, 80) JPEG     download (18).jfif
# RGB (80, 80) JPEG     download (19).jfif
# RGB (80, 80) JPEG     download (2).jfif
# RGB (80, 80) JPEG     download (20).jfif
# RGB (80, 80) JPEG     download (22).jfif
# RGB (80, 80) JPEG     download (23).jfif
# RGB (80, 80) JPEG     download (24).jfif
# RGB (80, 80) JPEG     download (25).jfif
# RGB (80, 80) JPEG     download (26).jfif
# RGB (80, 80) JPEG     download (27).jfif
# RGB (80, 80) JPEG     download (28).jfif
# RGB (80, 80) JPEG     download (29).jfif
# RGB (80, 80) JPEG     download (3).jfif
# RGB (80, 80) JPEG     download (30).jfif
# ...

# %%
# Trying to combine functions here

# %%
print_modeANDsize("CALIBRATION IMAGES/DarthVader - Copy - Copy/")
# Out:
# RGB (89, 50) JPEG     download (1).jfif
# RGB (66, 50) JPEG     download (10).jfif
# RGB (300, 168) JPEG     download (11).jfif
# RGB (225, 225) JPEG     download (12).jfif
# RGB (222, 227) JPEG     download (13).jfif
# RGB (218, 231) JPEG     download (14).jfif
# RGB (225, 225) JPEG     download (15).jfif
# RGB (300, 168) JPEG     download (16).jfif
# RGB (176, 287) JPEG     download (17).jfif
# RGB (225, 225) JPEG     download (18).jfif
# RGB (225, 225) JPEG     download (19).jfif
# RGB (50, 64) JPEG     download (2).jfif
# RGB (191, 264) JPEG     download (20).jfif
# RGB (225, 225) JPEG     download (22).jfif
# RGB (188, 268) JPEG     download (23).jfif
# RGB (173, 291) JPEG     download (24).jfif
# RGB (225, 225) JPEG     download (25).jfif
# RGB (310, 163) JPEG     download (26).jfif
# RGB (300, 168) JPEG     download (27).jfif
# RGB (234, 216) JPEG     download (28).jfif
# RGB (300, 168) JPEG     download (29).jfif
# RGB (82, 50) JPEG     download (3).jfif
# ...

# %%
process_image("CALIBRATION IMAGES/DarthVader - Copy - Copy/")
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# <ipython-input-50-7f80f08e108d> in <module>
# ----> 1 process_image("CALIBRATION IMAGES/DarthVader - Copy - Copy/")
#
# <ipython-input-49-12e3a8f7f15c> in process_image(path)
#       2     for item in os.listdir(path):
#       3         if os.path.isfile(path + item):
# ----> 4             im = Image.open(path + item)
#       5             if im.mode != 'RGB':
#       6                 im = convert_RGB(im)
#
# ~\Anaconda3\envs\NNfromscratch\lib\site-packages\PIL\Image.py in open(fp, mode)
#    2859     for message in accept_warnings:
#    2860         warnings.warn(message)
# -> 2861     raise UnidentifiedImageError(
#    2862         "cannot identify image file %r" % (filename if filename else fp)
#    2863     )
#
# ...
